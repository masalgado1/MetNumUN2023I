# %% [markdown]
# ![Captura de Pantalla 2023-03-06 a la(s) 7.48.15 p. m..png](data:image/png;base64,...)

# %% [markdown]
# ![Captura de Pantalla 2023-03-06 a la(s) 9.25.21 p. m..png](data:image/png;base64,...)

# %% [markdown]
# ![Captura de Pantalla 2023-03-06 a la(s) 9.25.35 p. m..png](data:image/png;base64,...)

# %% [markdown]
# ![Captura de Pantalla 2023-03-06 a la(s) 9.25.03 p. m..png](data:image/png;base64,...)
